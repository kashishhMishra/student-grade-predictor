# %%
import pandas as pd

data = {
    "hours_study": [1,2,3,4,5,6,7,8],
    "attendance": [50,55,60,65,70,75,80,90],
    "final_marks": [40,45,50,55,60,65,70,80]
}

df = pd.DataFrame(data)
print(df)

import seaborn as sns
import matplotlib.pyplot as plt

sns.heatmap(df.corr(), annot=True, cmap="coolwarm")
plt.show()
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

X = df[["hours_study", "attendance"]]
y = df["final_marks"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

model = LinearRegression()
model.fit(X_train, y_train)

pred = model.predict(X_test)

print("Predicted:", pred)
from sklearn.metrics import mean_squared_error

print("Error:", mean_squared_error(y_test, pred))
# Out:
#    hours_study  attendance  final_marks
# 0            1          50           40
# 1            2          55           45
# 2            3          60           50
# 3            4          65           55
# 4            5          70           60
# 5            6          75           65
# 6            7          80           70
# 7            8          90           80
# Predicted: [60.         79.80769231]
# Error: 0.018491124260357972
